# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
page = requests.get('https://www.spotrac.com/mlb/boston-red-sox/payroll/')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
page
# Out:
# <Response [200]>

# %%
node = soup.select('.teams')[0]
list(node.children)
[type(i) for i in list(node.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
table = list(node.children)[3]
list(table.children)
# [type(i) for i in list(table.children)]
# Out:
# ['\n', <thead>
#  <tr>
#  <th class="player">Active Players (25)</th>
#  <th class="center xs-hide">Age</th>
#  <th class="center">Pos.</th>
#  <th class="center xs-hide">Status</th>
#  <th class="center xs-hide">Waiver Options</th>
#  <th class="right xs-hide">Base Salary</th>
#  <th class="right xs-hide"><span class="info" title="The prorated portion of the signing bonus allocated to this year's salary cap.">Signing Bonus</span></th>
#  <th class="right xs-hide"><span class="info" title="">Incentives</span></th>
#  <th class=" right"><span class="info" title="The overall salary cap figure.">Total Salary</span></th>
#  <th class="right"><span class="info" title="The overall adjusted salary figure.">Adj. <br/>Salary</span></th>
#  <th class="center">Payroll %</th>
#  </tr>
#  </thead>, '\n', <tbody>
#  <tr>
#  <td class="player">
#  <span style="display:none">Price</span>
#  <a href="https://www.spotrac.com/redirect/player/7536/">David Price</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">32</span></td>
#  <td class=" center small"><span class="cap" title="">SP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$30,000,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$30,000,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$30,000,000</span></td>
#  <td class=" center ">12.70</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Martinez</span>
#  <a href="https://www.spotrac.com/redirect/player/8690/">J.D. Martinez</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
#  <td class=" center small"><span class="cap" title="">DH</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$23,750,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$23,750,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$23,750,000</span></td>
#  <td class=" center ">10.05</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Porcello</span>
#  <a href="https://www.spotrac.com/redirect/player/5235/">Rick Porcello</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
#  <td class=" center small"><span class="cap" title="">SP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$21,000,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">$125,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$21,125,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$21,125,000</span></td>
#  <td class=" center ">8.94</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Kimbrel</span>
#  <a href="https://www.spotrac.com/redirect/player/7233/">Craig Kimbrel</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
#  <td class=" center small"><span class="cap" title="">RP/CL</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$13,000,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$13,000,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$13,000,000</span></td>
#  <td class=" center ">5.50</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Sale</span>
#  <a href="https://www.spotrac.com/redirect/player/7278/">Chris Sale</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
#  <td class=" center small"><span class="cap" title="">SP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$12,500,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$12,500,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$12,500,000</span></td>
#  <td class=" center ">5.29</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Betts</span>
#  <a href="https://www.spotrac.com/redirect/player/15744/">Mookie Betts</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">25</span></td>
#  <td class=" center small"><span class="cap" title="">RF</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 1</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
#  <td class=" right xs-hide option-arbitration-settlement"><span class="cap info " title="Base / Arbitration Settlement">$10,500,000</span></td>
#  <td class=" right xs-hide option-arbitration-settlement"><span class="cap info" title="Signing Bonus / Arbitration Settlement">-</span></td>
#  <td class=" right xs-hide option-arbitration-settlement"><span class="cap info" title="Signing Bonus / Arbitration Settlement">-</span></td>
#  <td class=" right"><span class="cap option-arbitration-settlement " title="Total Salary including base salary and bonuses">$10,500,000 </span></td>
#  <td class="result right"><span class="cap option-arbitration-settlement " title="Total Adjusted Salary including base salary and bonuses">$10,500,000</span></td>
#  <td class=" center option-arbitration-settlement">4.44</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Bogaerts</span>
#  <a href="https://www.spotrac.com/redirect/player/14035/">Xander Bogaerts</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">25</span></td>
#  <td class=" center small"><span class="cap" title="">SS</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">3</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$7,050,000</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$7,050,000 </span></td>
#  <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$7,050,000</span></td>
#  <td class=" center option-arbitration-avoided">2.98</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Moreland</span>
#  <a href="https://www.spotrac.com/redirect/player/7560/">Mitch Moreland</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">32</span></td>
#  <td class=" center small"><span class="cap" title="">1B</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$6,500,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$6,500,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$6,500,000</span></td>
#  <td class=" center ">2.75</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Bradley</span>
#  <a href="https://www.spotrac.com/redirect/player/12166/">Jackie Bradley</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">28</span></td>
#  <td class=" center small"><span class="cap" title="">CF</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">1</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$6,100,000</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$6,100,000 </span></td>
#  <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$6,100,000</span></td>
#  <td class=" center option-arbitration-avoided">2.58</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Nunez</span>
#  <a href="https://www.spotrac.com/redirect/player/7465/">Eduardo Nunez</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">31</span></td>
#  <td class=" center small"><span class="cap" title="">2B</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$4,000,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$4,000,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$4,000,000</span></td>
#  <td class=" center ">1.69</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Kelly</span>
#  <a href="https://www.spotrac.com/redirect/player/11030/">Joe Kelly</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 3</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$3,825,000</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$3,825,000 </span></td>
#  <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$3,825,000</span></td>
#  <td class=" center option-arbitration-avoided">1.62</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Holt</span>
#  <a href="https://www.spotrac.com/redirect/player/11509/">Brock Holt</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
#  <td class=" center small"><span class="cap" title="">2B</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">1</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$2,225,000</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$2,225,000 </span></td>
#  <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$2,225,000</span></td>
#  <td class=" center option-arbitration-avoided">0.94</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Thornburg</span>
#  <a href="https://www.spotrac.com/redirect/player/11561/">Tyler Thornburg</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$2,050,000</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$2,050,000 </span></td>
#  <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$2,050,000</span></td>
#  <td class=" center option-arbitration-avoided">0.87</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Leon</span>
#  <a href="https://www.spotrac.com/redirect/player/10683/">Sandy Leon</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
#  <td class=" center small"><span class="cap" title="">C</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$1,950,000</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
#  <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$1,950,000 </span></td>
#  <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$1,950,000</span></td>
#  <td class=" center option-arbitration-avoided">0.83</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Pearce</span>
#  <a href="https://www.spotrac.com/redirect/player/7494/">Steven Pearce</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">35</span></td>
#  <td class=" center small"><span class="cap" title="">LF</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$6,250,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$6,250,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$1,500,000</span></td>
#  <td class=" center ">0.63</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Workman</span>
#  <a href="https://www.spotrac.com/redirect/player/14034/">Brandon Workman</a>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">1</span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$835,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$835,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$835,000</span></td>
#  <td class=" center ">0.35</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Barnes</span>
#  <a href="https://www.spotrac.com/redirect/player/14038/">Matt Barnes</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">28</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$605,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$605,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$605,000</span></td>
#  <td class=" center ">0.26</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Hembree</span>
#  <a href="https://www.spotrac.com/redirect/player/15653/">Heath Hembree</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$581,500</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$581,500 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$581,500</span></td>
#  <td class=" center ">0.25</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Swihart</span>
#  <a href="https://www.spotrac.com/redirect/player/14043/">Blake Swihart</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">26</span></td>
#  <td class=" center small"><span class="cap" title="">LF</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$563,500</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$563,500 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$563,500</span></td>
#  <td class=" center ">0.24</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Johnson</span>
#  <a href="https://www.spotrac.com/redirect/player/18038/">Brian Johnson</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">27</span></td>
#  <td class=" center small"><span class="cap" title="">SP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$548,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$548,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$548,000</span></td>
#  <td class=" center ">0.23</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Velazquez</span>
#  <a href="https://www.spotrac.com/redirect/player/22609/">Hector Velazquez</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$547,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$547,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$547,000</span></td>
#  <td class=" center ">0.23</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Lin</span>
#  <a href="https://www.spotrac.com/redirect/player/23730/">Tzu-Wei Lin</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">24</span></td>
#  <td class=" center small"><span class="cap" title="">SS</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$339,880</span></td>
#  <td class=" center ">0.14</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Poyner</span>
#  <a href="https://www.spotrac.com/redirect/player/25037/">Bobby Poyner</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">25</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">3</span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$278,350</span></td>
#  <td class=" center ">0.12</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Travis</span>
#  <a href="https://www.spotrac.com/redirect/player/17733/">Sam Travis</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">24</span></td>
#  <td class=" center small"><span class="cap" title="">1B</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$266,630</span></td>
#  <td class=" center ">0.11</td>
#  </tr>
#  <tr>
#  <td class="player">
#  <span style="display:none">Brasier</span>
#  <a href="https://www.spotrac.com/redirect/player/12089/">Ryan Brasier</a>
#  <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
#  </td>
#  <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
#  <td class=" center small"><span class="cap" title="">RP</span></td>
#  <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
#  <td class=" center small xs-hide"><span class="cap" title=""></span></td>
#  <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
#  <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
#  <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$249,050</span></td>
#  <td class=" center ">0.11</td>
#  </tr>
#  </tbody>, '\n']

# %%
tbody = list(table.children)[3]
list(tbody.children)
[type(i) for i in list(tbody.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
tr = list(tbody.children)[1]
[type(i) for i in list(tr.children)]
# print(len(list(tr.children)))
# list(tr.children)[11] # Returns salary
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
span = list(tr.children)[11]
span.get_text()
# Out:
# '$30,000,000'

# %%
my_list = []
for i in range(len(list(tbody.children))):
    if i%2==1:
        tr = list(tbody.children)[i]
        salary = list(tr.children)[11]
        string = salary.get_text().replace('$', '')
        string2 = string.replace(',', '')
        string2 = float(string2)
        my_list.append(string2)
print(f"Boston Red Sox - Active Player Salary Total: ${np.sum(my_list)}")
print(f"Boston Red Sox - Active Player Average Salary: ${np.mean(my_list)}")
# Out:
# Boston Red Sox - Active Player Salary Total: $156560000.0
# Boston Red Sox - Active Player Average Salary: $6262400.0

# %%
# How much does David Price make per pitch?

# How many innings? 9
# How many pitches? ~100/game
# What's his salary? $30,000,000
# How many games does the average pitcher play in? 32 games/season

# %%
tr = list(tbody.children)[1]
list(tr.children)[11]
# Out:
# <td class=" right xs-hide "><span class="cap info " title="Base">$30,000,000</span></td>

# %%
def pay_per_pitch(pitches, games_played):
    tr = list(tbody.children)[1]
    salary = list(tr.children)[11]
    salary = salary.get_text().replace('$', '')
    salary = salary.replace(',', '')
    salary = float(salary)
    per_pitch = salary / (pitches * games_played)
    return f"David Price gets paid ${per_pitch} per pitch **Rolls Eyes**"

# %%
pay_per_pitch(100, 32)
# Out:
# 'David Price gets paid $9375.0 per pitch **Rolls Eyes**'

# %%
import matplotlib.pyplot as plt

# %%
year = [2010, 2011, 2012, 2013, 2014, 2015]
salary = [15000000, 20000000, 18000000, 26000000, 22000000, 30000000]

# %%
plt.plot(year, salary)
plt.show()

# %%
pop = [30000000, 32000000, 33000000, 31000000, 320000000, 325000000]
year = [1960, 1970, 1980, 1990, 2000, 2010]

plt.scatter(pop, year)
plt.xscale('log')
plt.show()

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6] 

plt.hist(values, bins=3)
plt.show()

# %%
table
# Out:
# <table class="datatable">
# <thead>
# <tr>
# <th class="player">Active Players (25)</th>
# <th class="center xs-hide">Age</th>
# <th class="center">Pos.</th>
# <th class="center xs-hide">Status</th>
# <th class="center xs-hide">Waiver Options</th>
# <th class="right xs-hide">Base Salary</th>
# <th class="right xs-hide"><span class="info" title="The prorated portion of the signing bonus allocated to this year's salary cap.">Signing Bonus</span></th>
# <th class="right xs-hide"><span class="info" title="">Incentives</span></th>
# <th class=" right"><span class="info" title="The overall salary cap figure.">Total Salary</span></th>
# <th class="right"><span class="info" title="The overall adjusted salary figure.">Adj. <br/>Salary</span></th>
# <th class="center">Payroll %</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="player">
# <span style="display:none">Price</span>
# <a href="https://www.spotrac.com/redirect/player/7536/">David Price</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">32</span></td>
# <td class=" center small"><span class="cap" title="">SP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$30,000,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$30,000,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$30,000,000</span></td>
# <td class=" center ">12.70</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Martinez</span>
# <a href="https://www.spotrac.com/redirect/player/8690/">J.D. Martinez</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
# <td class=" center small"><span class="cap" title="">DH</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$23,750,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$23,750,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$23,750,000</span></td>
# <td class=" center ">10.05</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Porcello</span>
# <a href="https://www.spotrac.com/redirect/player/5235/">Rick Porcello</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
# <td class=" center small"><span class="cap" title="">SP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$21,000,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">$125,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$21,125,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$21,125,000</span></td>
# <td class=" center ">8.94</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Kimbrel</span>
# <a href="https://www.spotrac.com/redirect/player/7233/">Craig Kimbrel</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
# <td class=" center small"><span class="cap" title="">RP/CL</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$13,000,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$13,000,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$13,000,000</span></td>
# <td class=" center ">5.50</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Sale</span>
# <a href="https://www.spotrac.com/redirect/player/7278/">Chris Sale</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
# <td class=" center small"><span class="cap" title="">SP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$12,500,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$12,500,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$12,500,000</span></td>
# <td class=" center ">5.29</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Betts</span>
# <a href="https://www.spotrac.com/redirect/player/15744/">Mookie Betts</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">25</span></td>
# <td class=" center small"><span class="cap" title="">RF</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 1</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
# <td class=" right xs-hide option-arbitration-settlement"><span class="cap info " title="Base / Arbitration Settlement">$10,500,000</span></td>
# <td class=" right xs-hide option-arbitration-settlement"><span class="cap info" title="Signing Bonus / Arbitration Settlement">-</span></td>
# <td class=" right xs-hide option-arbitration-settlement"><span class="cap info" title="Signing Bonus / Arbitration Settlement">-</span></td>
# <td class=" right"><span class="cap option-arbitration-settlement " title="Total Salary including base salary and bonuses">$10,500,000 </span></td>
# <td class="result right"><span class="cap option-arbitration-settlement " title="Total Adjusted Salary including base salary and bonuses">$10,500,000</span></td>
# <td class=" center option-arbitration-settlement">4.44</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Bogaerts</span>
# <a href="https://www.spotrac.com/redirect/player/14035/">Xander Bogaerts</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">25</span></td>
# <td class=" center small"><span class="cap" title="">SS</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">3</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$7,050,000</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$7,050,000 </span></td>
# <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$7,050,000</span></td>
# <td class=" center option-arbitration-avoided">2.98</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Moreland</span>
# <a href="https://www.spotrac.com/redirect/player/7560/">Mitch Moreland</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">32</span></td>
# <td class=" center small"><span class="cap" title="">1B</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$6,500,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$6,500,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$6,500,000</span></td>
# <td class=" center ">2.75</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Bradley</span>
# <a href="https://www.spotrac.com/redirect/player/12166/">Jackie Bradley</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">28</span></td>
# <td class=" center small"><span class="cap" title="">CF</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">1</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$6,100,000</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$6,100,000 </span></td>
# <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$6,100,000</span></td>
# <td class=" center option-arbitration-avoided">2.58</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Nunez</span>
# <a href="https://www.spotrac.com/redirect/player/7465/">Eduardo Nunez</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">31</span></td>
# <td class=" center small"><span class="cap" title="">2B</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$4,000,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$4,000,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$4,000,000</span></td>
# <td class=" center ">1.69</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Kelly</span>
# <a href="https://www.spotrac.com/redirect/player/11030/">Joe Kelly</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 3</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$3,825,000</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$3,825,000 </span></td>
# <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$3,825,000</span></td>
# <td class=" center option-arbitration-avoided">1.62</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Holt</span>
# <a href="https://www.spotrac.com/redirect/player/11509/">Brock Holt</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
# <td class=" center small"><span class="cap" title="">2B</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">1</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$2,225,000</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$2,225,000 </span></td>
# <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$2,225,000</span></td>
# <td class=" center option-arbitration-avoided">0.94</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Thornburg</span>
# <a href="https://www.spotrac.com/redirect/player/11561/">Tyler Thornburg</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$2,050,000</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$2,050,000 </span></td>
# <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$2,050,000</span></td>
# <td class=" center option-arbitration-avoided">0.87</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Leon</span>
# <a href="https://www.spotrac.com/redirect/player/10683/">Sandy Leon</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
# <td class=" center small"><span class="cap" title="">C</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info " title="Base / Arbitration Avoided">$1,950,000</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right xs-hide option-arbitration-avoided"><span class="cap info" title="Signing Bonus / Arbitration Avoided">-</span></td>
# <td class=" right"><span class="cap option-arbitration-avoided " title="Total Salary including base salary and bonuses">$1,950,000 </span></td>
# <td class="result right"><span class="cap option-arbitration-avoided " title="Total Adjusted Salary including base salary and bonuses">$1,950,000</span></td>
# <td class=" center option-arbitration-avoided">0.83</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Pearce</span>
# <a href="https://www.spotrac.com/redirect/player/7494/">Steven Pearce</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">35</span></td>
# <td class=" center small"><span class="cap" title="">LF</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Vet</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$6,250,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$6,250,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$1,500,000</span></td>
# <td class=" center ">0.63</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Workman</span>
# <a href="https://www.spotrac.com/redirect/player/14034/">Brandon Workman</a>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Arb 2</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">1</span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$835,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$835,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$835,000</span></td>
# <td class=" center ">0.35</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Barnes</span>
# <a href="https://www.spotrac.com/redirect/player/14038/">Matt Barnes</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">28</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$605,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$605,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$605,000</span></td>
# <td class=" center ">0.26</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Hembree</span>
# <a href="https://www.spotrac.com/redirect/player/15653/">Heath Hembree</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$581,500</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$581,500 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$581,500</span></td>
# <td class=" center ">0.25</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Swihart</span>
# <a href="https://www.spotrac.com/redirect/player/14043/">Blake Swihart</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">26</span></td>
# <td class=" center small"><span class="cap" title="">LF</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$563,500</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$563,500 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$563,500</span></td>
# <td class=" center ">0.24</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Johnson</span>
# <a href="https://www.spotrac.com/redirect/player/18038/">Brian Johnson</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">27</span></td>
# <td class=" center small"><span class="cap" title="">SP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$548,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$548,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$548,000</span></td>
# <td class=" center ">0.23</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Velazquez</span>
# <a href="https://www.spotrac.com/redirect/player/22609/">Hector Velazquez</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">29</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$547,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$547,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$547,000</span></td>
# <td class=" center ">0.23</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Lin</span>
# <a href="https://www.spotrac.com/redirect/player/23730/">Tzu-Wei Lin</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">24</span></td>
# <td class=" center small"><span class="cap" title="">SS</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$339,880</span></td>
# <td class=" center ">0.14</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Poyner</span>
# <a href="https://www.spotrac.com/redirect/player/25037/">Bobby Poyner</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">25</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">3</span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$278,350</span></td>
# <td class=" center ">0.12</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Travis</span>
# <a href="https://www.spotrac.com/redirect/player/17733/">Sam Travis</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">24</span></td>
# <td class=" center small"><span class="cap" title="">1B</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">2</span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$266,630</span></td>
# <td class=" center ">0.11</td>
# </tr>
# <tr>
# <td class="player">
# <span style="display:none">Brasier</span>
# <a href="https://www.spotrac.com/redirect/player/12089/">Ryan Brasier</a>
# <span class="info" title="Two-Way Contract"><i class="fa fa-exchange"></i></span>
# </td>
# <td class=" center small xs-hide"><span class="cap" title="">30</span></td>
# <td class=" center small"><span class="cap" title="">RP</span></td>
# <td class=" center small xs-hide"><span class="cap" title="">Pre-Arb</span></td>
# <td class=" center small xs-hide"><span class="cap" title=""></span></td>
# <td class=" right xs-hide "><span class="cap info " title="Base">$545,000</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right xs-hide "><span class="cap info" title="Signing Bonus">-</span></td>
# <td class=" right"><span class="cap " title="Total Salary including base salary and bonuses">$545,000 </span></td>
# <td class="result right"><span class="cap " title="Total Adjusted Salary including base salary and bonuses">$249,050</span></td>
# <td class=" center ">0.11</td>
# </tr>
# </tbody>
# </table>
